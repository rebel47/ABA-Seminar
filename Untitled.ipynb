# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('final_m&a.csv')

# %%
train
# Out:
#         closedDate  dealvalue transaction_id   taget_id target_companytype  \
# 0       17-03-2003     30.305    IQTR4841274   IQ265308    Private Company
# 1       17-03-2003     30.305    IQTR4841274   IQ265308    Private Company
# 2       26-02-2003    148.400    IQTR6349813    IQ32586     Public Company
# 3       28-03-2003     28.360    IQTR3796458  IQ3796454    Private Company
# 4       11-03-2003     58.310    IQTR4803149   IQ183195    Private Company
# ...            ...        ...            ...        ...                ...
# 333393  25-10-2002    168.840    IQTR3207430   IQ127761    Private Company
# 333394  01-10-2002     25.690    IQTR4679141  IQ4614857    Private Company
# 333395  01-10-2002     48.740   IQTR23796902    IQ25107    Private Company
# 333396  22-11-2002    366.300   IQTR10120358  IQ9466547    Private Company
# 333397  26-11-2002     68.680    IQTR2004692  IQ1497356    Private Company
#
#          buyer_id        sourcefilename
# ...

# %%
train.isnull()
# Out:
#         closedDate  dealvalue  transaction_id  taget_id  target_companytype  \
# 0            False      False           False     False               False
# 1            False      False           False     False               False
# 2            False      False           False     False               False
# 3            False      False           False     False               False
# 4            False      False           False     False               False
# ...            ...        ...             ...       ...                 ...
# 333393       False      False           False     False               False
# 333394       False      False           False     False               False
# 333395       False      False           False     False               False
# 333396       False      False           False     False               False
# 333397       False      False           False     False               False
#
#         buyer_id  sourcefilename
# ...

# %%
sns.heatmap(train.isnull(), yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.set_style('whitegrid')
sns.countplot(x='target_companytype',data=train)
# Out:
# <Axes: xlabel='target_companytype', ylabel='count'>

# %%
sns.countplot(x='buyer_id',hue='target_companytype', data=train, palette='RdBu_r')
# Out:
# <Axes: xlabel='buyer_id', ylabel='count'>

# %%
sns.distplot(train['dealvalue'].dropna(),kde=False,color='red',bins=40)
# Out:
# C:\Users\aayya\AppData\Local\Temp\ipykernel_13352\2822918062.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['dealvalue'].dropna(),kde=False,color='red',bins=40)
# <Axes: xlabel='dealvalue'>

# %%
print(len(pd.unique(train['buyer_id'])))
# Out:
# 4679

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='target_companytype',y='dealvalue',data=train,palette='winter')
# Out:
# <Axes: xlabel='target_companytype', ylabel='dealvalue'>

# %%
# new_dealvalue = train['dealvalue'] < 20000
train = train[train['dealvalue'] < 350]

# %%
train
# Out:
#         closedDate  dealvalue transaction_id     taget_id target_companytype  \
# 0       17-03-2003     30.305    IQTR4841274     IQ265308    Private Company
# 1       17-03-2003     30.305    IQTR4841274     IQ265308    Private Company
# 3       28-03-2003     28.360    IQTR3796458    IQ3796454    Private Company
# 5       07-03-2003     49.200    IQTR4765543      IQ26873     Public Company
# 7       10-02-2003     31.070    IQTR4473376      IQ26240    Private Company
# ...            ...        ...            ...          ...                ...
# 333390  25-10-2002     39.475   IQTR10978356    IQ1030012    Private Company
# 333391  08-10-2002     34.440    IQTR3259059  IQ136756465    Assets/Products
# 333392  07-10-2002     25.450    IQTR3259871    IQ3259859    Private Company
# 333394  01-10-2002     25.690    IQTR4679141    IQ4614857    Private Company
# 333395  01-10-2002     48.740   IQTR23796902      IQ25107    Private Company
#
#          buyer_id        sourcefilename
# ...

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='target_companytype',y='dealvalue',data=train,palette='winter')
# Out:
# <Axes: xlabel='target_companytype', ylabel='dealvalue'>

# %%
train['target_companytype'].value_counts()
# Out:
# Private Company                      251512
# Assets/Products                       59087
# Public Company                        17797
# Foundation/Charitable Institution       113
# Private Investment Firm                  22
# Name: target_companytype, dtype: int64
