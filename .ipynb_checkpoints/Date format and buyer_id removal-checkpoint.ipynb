# %%
import pandas as pd

# %%
data = pd.read_csv("Merged Endfile/final.csv")

# %%
data
# Out:
#         closedDate  dealvalue transaction_id   taget_id target_companytype  \
# 0        3/17/2003     30.305    IQTR4841274   IQ265308    Private Company
# 1        3/17/2003     30.305    IQTR4841274   IQ265308    Private Company
# 2        2/26/2003    148.400    IQTR6349813    IQ32586     Public Company
# 3        3/28/2003     28.360    IQTR3796458  IQ3796454    Private Company
# 4       03-11-2003     58.310    IQTR4803149   IQ183195    Private Company
# ...            ...        ...            ...        ...                ...
# 341604  10/25/2002    168.840    IQTR3207430   IQ127761    Private Company
# 341605  10-01-2002     25.690    IQTR4679141  IQ4614857    Private Company
# 341606  10-01-2002     48.740   IQTR23796902    IQ25107    Private Company
# 341607  11/22/2002    366.300   IQTR10120358  IQ9466547    Private Company
# 341608  11/26/2002     68.680    IQTR2004692  IQ1497356    Private Company
#
#          buyer_id        sourcefilename
# ...

# %%
data.describe()
# Out:
#            dealvalue
# count  341609.000000
# mean      476.886012
# std      2984.645610
# min         5.233333
# 25%        40.785000
# 50%        82.130000
# 75%       225.890000
# max     87278.600000

# %%
data.shape
# Out:
# (341609, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341609 entries, 0 to 341608
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   closedDate          341609 non-null  object
#  1   dealvalue           341609 non-null  float64
#  2   transaction_id      341609 non-null  object
#  3   taget_id            341609 non-null  object
#  4   target_companytype  341609 non-null  object
#  5   buyer_id            341609 non-null  object
#  6   sourcefilename      341609 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 18.2+ MB

# %%
data.tail(20)
# Out:
#         closedDate   dealvalue transaction_id     taget_id target_companytype  \
# 341589  10/30/2002  337.596667    IQTR3461236   IQ11777420    Private Company
# 341590  10/30/2002  337.596667    IQTR3461236   IQ11777420    Private Company
# 341591  10/30/2002  337.596667    IQTR3461236   IQ11777420    Private Company
# 341592  11/22/2002   18.560000   IQTR12188994      IQ29589    Private Company
# 341593  11/22/2002   18.560000   IQTR12188994      IQ29589    Private Company
# 341594  10/28/2002  118.020000    IQTR3452556     IQ706022    Private Company
# 341595  10-07-2002  173.030000    IQTR3255898    IQ2462067    Private Company
# 341596  10-01-2002   96.470000    IQTR2990944      IQ30219    Private Company
# 341597  10-09-2002  107.010000    IQTR3552802      IQ24210    Private Company
# 341598  11-08-2002   38.060000    IQTR3418531    IQ3418516    Private Company
# 341599  10/16/2002   30.000000   IQTR27291220   IQ27291155    Private Company
# ...

# %%
data['closedDate'] = pd.to_datetime(df['closedDate'])

# %%
data
# Out:
#        closedDate  dealvalue transaction_id   taget_id target_companytype  \
# 0      2003-03-17     30.305    IQTR4841274   IQ265308    Private Company
# 1      2003-03-17     30.305    IQTR4841274   IQ265308    Private Company
# 2      2003-02-26    148.400    IQTR6349813    IQ32586     Public Company
# 3      2003-03-28     28.360    IQTR3796458  IQ3796454    Private Company
# 4      2003-03-11     58.310    IQTR4803149   IQ183195    Private Company
# ...           ...        ...            ...        ...                ...
# 341604 2002-10-25    168.840    IQTR3207430   IQ127761    Private Company
# 341605 2002-10-01     25.690    IQTR4679141  IQ4614857    Private Company
# 341606 2002-10-01     48.740   IQTR23796902    IQ25107    Private Company
# 341607 2002-11-22    366.300   IQTR10120358  IQ9466547    Private Company
# 341608 2002-11-26     68.680    IQTR2004692  IQ1497356    Private Company
#
#          buyer_id        sourcefilename
# ...

# %%
data.head(20)
# Out:
#    closedDate  dealvalue transaction_id    taget_id target_companytype  \
# 0  2003-03-17     30.305    IQTR4841274    IQ265308    Private Company
# 1  2003-03-17     30.305    IQTR4841274    IQ265308    Private Company
# 2  2003-02-26    148.400    IQTR6349813     IQ32586     Public Company
# 3  2003-03-28     28.360    IQTR3796458   IQ3796454    Private Company
# 4  2003-03-11     58.310    IQTR4803149    IQ183195    Private Company
# 5  2003-03-07     49.200    IQTR4765543     IQ26873     Public Company
# 6  2003-01-30    635.480    IQTR4338514   IQ4338497    Assets/Products
# 7  2003-02-10     31.070    IQTR4473376     IQ26240    Private Company
# 8  2003-02-27     61.010   IQTR12190445  IQ12190434    Private Company
# 9  2003-03-18    211.590   IQTR11737157  IQ11737122    Assets/Products
# 10 2003-03-26    686.810    IQTR4915269     IQ32271    Private Company
# 11 2003-02-13     58.130    IQTR4524606   IQ4524474    Assets/Products
# ...

# %%
# Out:
# 0       IQ18759
# 1       IQ21407
# 2       IQ26449
# 3      IQ327481
# 4       IQ20803
# 5       IQ30239
# 6      IQ385872
# 7      IQ293711
# 8      IQ409298
# 9      IQ382553
# 10    IQ6618085
# 11      IQ33420
# 12            -
# 13     IQ139677
# 14     IQ318668
# 15     IQ695365
# 16     IQ657860
# 17     IQ321244
# 18     IQ301667
# 19      IQ28871
# Name: buyer_id, dtype: object

# %%
data = data[data['buyer_id'] != '-']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# ...

# %%
data['buyer_id'].head(20)
# Out:
# 0       IQ18759
# 1       IQ21407
# 2       IQ26449
# 3      IQ327481
# 4       IQ20803
# 5       IQ30239
# 6      IQ385872
# 7      IQ293711
# 8      IQ409298
# 9      IQ382553
# 10    IQ6618085
# 11      IQ33420
# 13     IQ139677
# 14     IQ318668
# 15     IQ695365
# 16     IQ657860
# 17     IQ321244
# 18     IQ301667
# 19      IQ28871
# 20      IQ34235
# Name: buyer_id, dtype: object

# %%
data.to_csv('removeBuyerNull.csv')

# %%
df=pd.read_csv('removeBuyerNull.csv')
df
# Out:
#         Unnamed: 0  closedDate  dealvalue transaction_id   taget_id  \
# 0                0   3/17/2003     30.305    IQTR4841274   IQ265308
# 1                1   3/17/2003     30.305    IQTR4841274   IQ265308
# 2                2   2/26/2003    148.400    IQTR6349813    IQ32586
# 3                3   3/28/2003     28.360    IQTR3796458  IQ3796454
# 4                4  03-11-2003     58.310    IQTR4803149   IQ183195
# ...            ...         ...        ...            ...        ...
# 333393      341604  10/25/2002    168.840    IQTR3207430   IQ127761
# 333394      341605  10-01-2002     25.690    IQTR4679141  IQ4614857
# 333395      341606  10-01-2002     48.740   IQTR23796902    IQ25107
# 333396      341607  11/22/2002    366.300   IQTR10120358  IQ9466547
# 333397      341608  11/26/2002     68.680    IQTR2004692  IQ1497356
#
#        target_companytype   buyer_id        sourcefilename
# 0         Private Company    IQ18759  2003\cq1\endfile.csv
# ...

# %%
df = df[df['buyer_id'] != '-']

# %%
df.head(20)
# Out:
#     Unnamed: 0  closedDate  dealvalue transaction_id    taget_id  \
# 0            0   3/17/2003     30.305    IQTR4841274    IQ265308
# 1            1   3/17/2003     30.305    IQTR4841274    IQ265308
# 2            2   2/26/2003    148.400    IQTR6349813     IQ32586
# 3            3   3/28/2003     28.360    IQTR3796458   IQ3796454
# 4            4  03-11-2003     58.310    IQTR4803149    IQ183195
# 5            5  03-07-2003     49.200    IQTR4765543     IQ26873
# 6            6   1/30/2003    635.480    IQTR4338514   IQ4338497
# 7            7  02-10-2003     31.070    IQTR4473376     IQ26240
# 8            8   2/27/2003     61.010   IQTR12190445  IQ12190434
# 9            9   3/18/2003    211.590   IQTR11737157  IQ11737122
# 10          10   3/26/2003    686.810    IQTR4915269     IQ32271
# 11          11   2/13/2003     58.130    IQTR4524606   IQ4524474
# 12          13  02-10-2003   2514.900    IQTR4481344    IQ257462
# ...

# %%
df['closedDate'] = pd.to_datetime(df['closedDate'])

# %%
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.head(20)
#
# NameError: name 'df' is not defined

# %%
df.to_csv('removeBuyerNull.csv')

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
unique_buyer_ids = data['buyer_id'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 unique_buyer_ids = data['buyer_id'].unique()
#
# NameError: name 'data' is not defined

# %%
pdf = pd.read_csv('final_m&a.csv')

# %%
pdf.describe()
# Out:
#            dealvalue
# count  333398.000000
# mean      484.577639
# std      3020.303974
# min         5.233333
# 25%        40.750000
# 50%        82.700000
# 75%       228.830000
# max     87278.600000
